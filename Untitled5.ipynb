# %% [markdown]
# # 台師大各科系修讀輔系相關資料

# %%
import pandas as pd

df = pd.read_csv('輔系.csv')

df.head()
# Out:
#        學校名稱     系所代碼         系所名稱     學制班別  109學年修讀輔系人次小計  109學年修讀輔系人次男  \
# 0  國立臺灣師範大學  1111001         教育學系  學士班(日間)            154            44
# 1  國立臺灣師範大學  1113018       特殊教育學系  學士班(日間)             37             4
# 2  國立臺灣師範大學  1116079   學習科學學士學位學程  學士班(日間)              5             4
# 3  國立臺灣師範大學  1131004  公民教育與活動領導學系  學士班(日間)             54            27
# 4  國立臺灣師範大學  1131009       社會教育學系  學士班(日間)             39             6
#
#    109學年修讀輔系人次女  109學年科系總人數  108學年修讀輔系人次小計  108學年修讀輔系人次男  108學年修讀輔系人次女  \
# 0           110         267          150.0          33.0         117.0
# 1            33         167           27.0           3.0          24.0
# 2             1          61            5.0           4.0           1.0
# 3            27         364           54.0          24.0          30.0
# 4            33         227           26.0           3.0          23.0
#
#    108學年科系總人數
# 0       260.0
# 1       172.0
# 2        48.0
# 3       354.0
# 4       208.0

# %%
import pandas as pd

df = pd.read_csv('輔系.csv', header=0)

print(df)
# Out:
#         學校名稱      系所代碼           系所名稱  109學年修讀輔系人次小計  109學年修讀輔系人次男  \
# 0   國立臺灣師範大學   1111001           教育學系            154            44
# 1   國立臺灣師範大學   1113018         特殊教育學系             37             4
# 2   國立臺灣師範大學   1116079     學習科學學士學位學程              5             4
# 3   國立臺灣師範大學   1131004    公民教育與活動領導學系             54            27
# 4   國立臺灣師範大學   1131009         社會教育學系             39             6
# 5   國立臺灣師範大學   1131017    健康促進與衛生教育學系             18             1
# 6   國立臺灣師範大學   1141007      人類發展與家庭學系             39             6
# 7   國立臺灣師範大學   1141010         工業教育學系             13            10
# 8   國立臺灣師範大學   1141015           體育學系              7             3
# 9   國立臺灣師範大學   1199021        教育學院學士班             12             6
# 10  國立臺灣師範大學   1199022  科技應用與人力資源發展學系              9             8
# 11  國立臺灣師範大學   2112037           設計學系              6             2
# 12  國立臺灣師範大學   2131023           美術學系              9             0
# ...

# %% [markdown]
# 1.台師大於109學年修讀輔系的人數為多少?

# %%
column1_total = df['109學年修讀輔系人次小計'].sum()

# %%
print(column1_total)
# Out:
# 753

# %% [markdown]
# 2.台師大於108學年修讀輔系的人數為多少?

# %%
column1_total = df['108學年修讀輔系人次小計'].sum()

# %%
print(column1_total)
# Out:
# 673.0

# %% [markdown]
# 3.台師大於109學年各科系修讀輔系人數占該科系人數的比率為何?

# %%
ratio = df['109學年修讀輔系人次小計'] / df['109學年科系總人數']
print(ratio)
# Out:
# 0     0.576779
# 1     0.221557
# 2     0.081967
# 3     0.148352
# 4     0.171806
# 5     0.104651
# 6     0.126623
# 7     0.090278
# 8     0.027237
# 9     0.272727
# 10    0.038462
# 11    0.037267
# 12    0.046154
# 13    0.049822
# 14    0.116279
# 15    0.069959
# 16    0.077670
# 17    0.107656
# 18    0.102273
# 19    0.079823
# 20    0.093407
# 21    0.085174
# 22    0.091324
# 23    0.021858
# 24    0.082988
# 25    0.089844
# 26    0.043011
# 27    0.075163
# 28    0.044872
# 29    0.045627
# 30    0.043928
# 31    0.016327
# 32    0.036082
# 33    0.088889
# 34    0.013953
# 35    0.040000
# 36    0.003559
# dtype: float64

# %% [markdown]
# 4.台師大於108學年各科系修讀輔系人數占該科系人數的比率為何?

# %%
ratio = df['108學年修讀輔系人次小計'] / df['108學年科系總人數']
print(ratio)
# Out:
# 0     0.576923
# 1     0.156977
# 2     0.104167
# 3     0.152542
# 4     0.125000
# 5     0.125828
# 6     0.137500
# 7     0.116438
# 8     0.019455
# 9          NaN
# 10    0.009009
# 11    0.052288
# 12    0.060440
# 13    0.018657
# 14    0.208333
# 15    0.072340
# 16    0.146497
# 17    0.034031
# 18    0.494624
# 19    0.054054
# 20    0.131579
# 21    0.068404
# 22    0.010256
# 23    0.060773
# 24    0.030702
# 25    0.008584
# 26    0.254545
# 27    0.018987
# 28    0.077419
# 29    0.069106
# 30    0.013441
# 31    0.028708
# 32    0.016949
# 33    0.206897
# 34    0.004950
# 35    0.020000
# 36         NaN
# dtype: float64

# %% [markdown]
# 5.台師大109學年各科系男性占修讀輔系人數的比率為何?

# %%
ratio = df['109學年修讀輔系人次男'] / df['109學年修讀輔系人次小計']
print(ratio)
# Out:
# 0     0.285714
# 1     0.108108
# 2     0.800000
# 3     0.500000
# 4     0.153846
# 5     0.055556
# 6     0.153846
# 7     0.769231
# 8     0.428571
# 9     0.500000
# 10    0.888889
# 11    0.333333
# 12    0.000000
# 13    0.214286
# 14    0.200000
# 15    0.294118
# 16    0.166667
# 17    0.111111
# 18    0.444444
# 19    0.138889
# 20    0.117647
# 21    0.629630
# 22    0.400000
# 23    0.250000
# 24    0.350000
# 25    0.478261
# 26    0.250000
# 27    0.521739
# 28    0.428571
# 29    0.666667
# 30    0.529412
# 31    0.750000
# 32    0.571429
# 33    1.000000
# 34    0.333333
# 35    1.000000
# 36    0.000000
# dtype: float64

# %% [markdown]
# 6.台師大108學年各科系男性占修讀輔系人數的比率為何?

# %%
ratio = df['108學年修讀輔系人次男'] / df['108學年修讀輔系人次小計']
print(ratio)
# Out:
# 0     0.220000
# 1     0.111111
# 2     0.800000
# 3     0.444444
# 4     0.115385
# 5     0.315789
# 6     0.113636
# 7     0.647059
# 8     0.000000
# 9          NaN
# 10    0.000000
# 11    0.000000
# 12    0.181818
# 13    0.000000
# 14    0.333333
# 15    0.235294
# 16    0.086957
# 17    0.230769
# 18    0.282609
# 19    0.166667
# 20    0.600000
# 21    0.476190
# 22    0.000000
# 23    0.272727
# 24    0.571429
# 25    0.500000
# 26    0.714286
# 27    0.500000
# 28    0.583333
# 29    0.588235
# 30    0.600000
# 31    0.500000
# 32    1.000000
# 33    0.666667
# 34    1.000000
# 35    0.000000
# 36         NaN
# dtype: float64

# %%
7.台師大109學年各科系女性占修讀輔系人數的比率為何?

# %%
ratio = df['109學年修讀輔系人次女'] / df['109學年修讀輔系人次小計']
print(ratio)
# Out:
# 0     0.714286
# 1     0.891892
# 2     0.200000
# 3     0.500000
# 4     0.846154
# 5     0.944444
# 6     0.846154
# 7     0.230769
# 8     0.571429
# 9     0.500000
# 10    0.111111
# 11    0.666667
# 12    1.000000
# 13    0.785714
# 14    0.800000
# 15    0.705882
# 16    0.833333
# 17    0.888889
# 18    0.555556
# 19    0.861111
# 20    0.882353
# 21    0.370370
# 22    0.600000
# 23    0.750000
# 24    0.650000
# 25    0.521739
# 26    0.750000
# 27    0.478261
# 28    0.571429
# 29    0.333333
# 30    0.470588
# 31    0.250000
# 32    0.428571
# 33    0.000000
# 34    0.666667
# 35    0.000000
# 36    1.000000
# dtype: float64

# %%
8.台師大108學年各科系女性占修讀輔系人數的比率為何?

# %%
ratio = df['108學年修讀輔系人次女'] / df['108學年修讀輔系人次小計']
print(ratio)
# Out:
# 0     0.780000
# 1     0.888889
# 2     0.200000
# 3     0.555556
# 4     0.884615
# 5     0.684211
# 6     0.886364
# 7     0.352941
# 8     1.000000
# 9          NaN
# 10    1.000000
# 11    1.000000
# 12    0.818182
# 13    1.000000
# 14    0.666667
# 15    0.764706
# 16    0.913043
# 17    0.769231
# 18    0.717391
# 19    0.833333
# 20    0.400000
# 21    0.523810
# 22    1.000000
# 23    0.727273
# 24    0.428571
# 25    0.500000
# 26    0.285714
# 27    0.500000
# 28    0.416667
# 29    0.411765
# 30    0.400000
# 31    0.500000
# 32    0.000000
# 33    0.333333
# 34    0.000000
# 35    1.000000
# 36         NaN
# dtype: float64

# %% [markdown]
# 9.台師大108年和109年各科系人數差為何?

# %%
df = df['109學年科系總人數'] - df['108學年科系總人數']

# %%
print(df)
# Out:
# 0      7.0
# 1     -5.0
# 2     13.0
# 3     10.0
# 4     19.0
# 5     21.0
# 6    -12.0
# 7     -2.0
# 8      0.0
# 9      NaN
# 10    12.0
# 11     8.0
# 12    13.0
# 13    13.0
# 14    14.0
# 15     8.0
# 16    -5.0
# 17    36.0
# 18    -5.0
# 19     7.0
# 20    -8.0
# 21    10.0
# 22    24.0
# 23     2.0
# 24    13.0
# 25    23.0
# 26    38.0
# 27   -10.0
# 28     1.0
# 29    17.0
# 30    15.0
# 31    36.0
# 32    17.0
# 33    16.0
# 34    13.0
# 35    25.0
# 36     2.0
# dtype: float64

# %% [markdown]
# 10.台師大108年和109年各科系輔系人數差為何?

# %% [markdown]
# df = df['109學年修讀輔系人次小計'] - df['108學年修讀輔系人次小計']

# %%
print(df)
# Out:
# 0      7.0
# 1     -5.0
# 2     13.0
# 3     10.0
# 4     19.0
# 5     21.0
# 6    -12.0
# 7     -2.0
# 8      0.0
# 9      NaN
# 10    12.0
# 11     8.0
# 12    13.0
# 13    13.0
# 14    14.0
# 15     8.0
# 16    -5.0
# 17    36.0
# 18    -5.0
# 19     7.0
# 20    -8.0
# 21    10.0
# 22    24.0
# 23     2.0
# 24    13.0
# 25    23.0
# 26    38.0
# 27   -10.0
# 28     1.0
# 29    17.0
# 30    15.0
# 31    36.0
# 32    17.0
# 33    16.0
# 34    13.0
# 35    25.0
# 36     2.0
# dtype: float64
