# %%
import pandas as pd

df = pd.read_csv('輔系.csv')

df.head()
# Out:
#    學年度  學期 設立別  學校類別  學校統計處代碼      學校名稱     系所代碼         系所名稱     學制班別  \
# 0  109   1  公立  一般大學        4  國立臺灣師範大學  1111001         教育學系  學士班(日間)
# 1  109   1  公立  一般大學        4  國立臺灣師範大學  1113018       特殊教育學系  學士班(日間)
# 2  109   1  公立  一般大學        4  國立臺灣師範大學  1116079   學習科學學士學位學程  學士班(日間)
# 3  109   1  公立  一般大學        4  國立臺灣師範大學  1131004  公民教育與活動領導學系  學士班(日間)
# 4  109   1  公立  一般大學        4  國立臺灣師範大學  1131009       社會教育學系  學士班(日間)
#
#    修讀輔系人次小計  修讀輔系人次男  修讀輔系人次女
# 0       154       44      110
# 1        37        4       33
# 2         5        4        1
# 3        54       27       27
# 4        39        6       33

# %%
df = pd.read_csv('輔系.csv', names=['學年度', '學期', '設立別', '學校類別', '學校統計處代碼',  '學校名稱',  '系所代碼',  '系所名稱', '學制班別', '修讀輔系人次小計', '修讀輔系人次男', '修讀輔系人次女'])

# %%
import pandas as pd

df = pd.read_csv('輔系.csv', header=0)

print(df)
# Out:
#     學年度  學期 設立別  學校類別  學校統計處代碼      學校名稱      系所代碼           系所名稱     學制班別  \
# 0   109   1  公立  一般大學        4  國立臺灣師範大學   1111001           教育學系  學士班(日間)
# 1   109   1  公立  一般大學        4  國立臺灣師範大學   1113018         特殊教育學系  學士班(日間)
# 2   109   1  公立  一般大學        4  國立臺灣師範大學   1116079     學習科學學士學位學程  學士班(日間)
# 3   109   1  公立  一般大學        4  國立臺灣師範大學   1131004    公民教育與活動領導學系  學士班(日間)
# 4   109   1  公立  一般大學        4  國立臺灣師範大學   1131009         社會教育學系  學士班(日間)
# 5   109   1  公立  一般大學        4  國立臺灣師範大學   1131017    健康促進與衛生教育學系  學士班(日間)
# 6   109   1  公立  一般大學        4  國立臺灣師範大學   1141007      人類發展與家庭學系  學士班(日間)
# 7   109   1  公立  一般大學        4  國立臺灣師範大學   1141010         工業教育學系  學士班(日間)
# 8   109   1  公立  一般大學        4  國立臺灣師範大學   1141015           體育學系  學士班(日間)
# 9   109   1  公立  一般大學        4  國立臺灣師範大學   1199021        教育學院學士班  學士班(日間)
# 10  109   1  公立  一般大學        4  國立臺灣師範大學   1199022  科技應用與人力資源發展學系  學士班(日間)
# ...

# %%
column1_total = df['修讀輔系人次小計'].sum()

# %%
print(column1_total)
# Out:
# 753

# %%
ratio = df['修讀輔系人次男'] / df['修讀輔系人次女']
print(ratio)
# Out:
# 0     0.400000
# 1     0.121212
# 2     4.000000
# 3     1.000000
# 4     0.181818
# 5     0.058824
# 6     0.181818
# 7     3.333333
# 8     0.750000
# 9     1.000000
# 10    8.000000
# 11    0.500000
# 12    0.000000
# 13    0.272727
# 14    0.250000
# 15    0.416667
# 16    0.200000
# 17    0.125000
# 18    0.800000
# 19    0.161290
# 20    0.133333
# 21    1.700000
# 22    0.666667
# 23    0.333333
# 24    0.538462
# 25    0.916667
# 26    0.333333
# 27    1.090909
# 28    0.750000
# 29    2.000000
# 30    1.125000
# 31    3.000000
# 32    1.333333
# 33         inf
# 34    0.500000
# 35         inf
# 36    0.000000
# dtype: float64
